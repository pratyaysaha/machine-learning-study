# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/pandas/pokemon_data.csv')

# %%
df.head(9)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
col= np.array(df.columns)
col
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype=object)

# %%
col[1:5]
# Out:
# array(['Name', 'Type 1', 'Type 2', 'HP'], dtype=object)

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Name', 'HP', "Type 1"]][9:21]
# Out:
#                        Name  HP  Type 1
# 9                  Squirtle  44   Water
# 10                Wartortle  59   Water
# 11                Blastoise  79   Water
# 12  BlastoiseMega Blastoise  79   Water
# 13                 Caterpie  45     Bug
# 14                  Metapod  50     Bug
# 15               Butterfree  60     Bug
# 16                   Weedle  40     Bug
# 17                   Kakuna  45     Bug
# 18                 Beedrill  65     Bug
# 19    BeedrillMega Beedrill  65     Bug
# 20                   Pidgey  40  Normal

# %%
df.iloc[9:17]
# Out:
#      #                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 9    7                 Squirtle  Water     NaN  44      48       65       50
# 10   8                Wartortle  Water     NaN  59      63       80       65
# 11   9                Blastoise  Water     NaN  79      83      100       85
# 12   9  BlastoiseMega Blastoise  Water     NaN  79     103      120      135
# 13  10                 Caterpie    Bug     NaN  45      30       35       20
# 14  11                  Metapod    Bug     NaN  50      20       55       25
# 15  12               Butterfree    Bug  Flying  60      45       50       90
# 16  13                   Weedle    Bug  Poison  40      35       30       20
#
#     Sp. Def  Speed  Generation  Legendary
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 13       20     45           1      False
# ...

# %%
# To find the attack of Wartortle residing at row index 10
df.iloc[10,5]
# Out:
# 63

# %%
df.iloc[10:15,5:8]
# Out:
#     Attack  Defense  Sp. Atk
# 10      63       80       65
# 11      83      100       85
# 12     103      120      135
# 13      30       35       20
# 14      20       55       25

# %%
df.iloc[10,5:8].sum()
# Out:
# 208

# %%
df.iloc[14,4:10].sum()
# Out:
# 205

# %%
# Selection rows based on one condition per column
df.loc[(df['Type 1'] == 'Water') | (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison  45      49       49       65
# 1      2                Ivysaur  Grass  Poison  60      62       63       80
# 2      3               Venusaur  Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 9      7               Squirtle  Water     NaN  44      48       65       50
# ..   ...                    ...    ...     ...  ..     ...      ...      ...
# 724  656                Froakie  Water     NaN  41      56       40       62
# 725  657              Frogadier  Water     NaN  54      63       52       83
# 726  658               Greninja  Water    Dark  72      95       67      103
# 762  692              Clauncher  Water     NaN  50      53       62       58
# 763  693              Clawitzer  Water     NaN  71      73       88      120
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[ ( (df['Type 1'] == 'Water') | (df['Type 1'] == 'Bug') ) & (df['Type 2']== 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 16    13                 Weedle    Bug  Poison  40      35       30       20
# 17    14                 Kakuna    Bug  Poison  45      25       50       25
# 18    15               Beedrill    Bug  Poison  65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison  65     150       40       15
# 53    48                Venonat    Bug  Poison  60      55       50       40
# 54    49               Venomoth    Bug  Poison  70      65       60       90
# 78    72              Tentacool  Water  Poison  40      40       35       50
# 79    73             Tentacruel  Water  Poison  80      70       65       80
# 181  167               Spinarak    Bug  Poison  40      60       40       40
# 182  168                Ariados    Bug  Poison  70      90       70       60
# 227  211               Qwilfish  Water  Poison  65      95       75       55
# ...

# %%
df.loc[ ( (df['Type 1'] == 'Water') | (df['Type 1'] == 'Bug') ) & (df['Type 2']== 'Poison') , ['Name', 'HP']]
# Out:
#                       Name  HP
# 16                  Weedle  40
# 17                  Kakuna  45
# 18                Beedrill  65
# 19   BeedrillMega Beedrill  65
# 53                 Venonat  60
# 54                Venomoth  70
# 78               Tentacool  40
# 79              Tentacruel  80
# 181               Spinarak  40
# 182                Ariados  70
# 227               Qwilfish  65
# 292                 Dustox  60
# 603               Venipede  30
# 604             Whirlipede  40
# 605              Scolipede  60

# %%
df.loc[0:2]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df.iloc[0:2]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %%
df_1 = pd.DataFrame([[1,2,3],[3,4,5]], columns=["T1", "T2", "T3"])
df_1
# Out:
#    T1  T2  T3
# 0   1   2   3
# 1   3   4   5

# %%
df_2 = pd.DataFrame([[1,2,3],[3,4,5]],index=["Potol", "Momo"], columns=["T1", "T2", "T3"])
df_2
# Out:
#        T1  T2  T3
# Potol   1   2   3
# Momo    3   4   5

# %%
df_2.iloc[0:2, 1:3]
# Out:
#        T2  T3
# Potol   2   3
# Momo    4   5

# %%
df_2.loc["Potol": "Momo" , "T2": "T3" ]
# Out:
#        T2  T3
# Potol   2   3
# Momo    4   5

# %%
df[45:50]
# Out:
#      #        Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 45  40  Wigglytuff  Normal   Fairy  140      70       45       85       50
# 46  41       Zubat  Poison  Flying   40      45       35       30       40
# 47  42      Golbat  Poison  Flying   75      80       70       65       75
# 48  43      Oddish   Grass  Poison   45      50       55       75       65
# 49  44       Gloom   Grass  Poison   60      65       70       85       75
#
#     Speed  Generation  Legendary
# 45     45           1      False
# 46     55           1      False
# 47     90           1      False
# 48     30           1      False
# 49     40           1      False
